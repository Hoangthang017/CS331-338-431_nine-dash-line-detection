# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoangthang017/CS331-338-431_nine-dash-line-detection/blob/main/FeatureExtractionUsingAlexnet/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# kết nối với gg.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# thêm thư viện.
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# đọc dữ liệu từ các file .txt thông qua thư viện numpy.
feature_FC1 = np.loadtxt('/content/drive/MyDrive/Data Nine-Dash-Lines/DataFrame/FC1_features_2.txt')
feature_FC2 = np.loadtxt('/content/drive/MyDrive/Data Nine-Dash-Lines/DataFrame/FC2_features_2.txt')


labels_FC1 = np.loadtxt('/content/drive/MyDrive/Data Nine-Dash-Lines/DataFrame/FC1_labels_2.txt')
labels_FC2 = np.loadtxt('/content/drive/MyDrive/Data Nine-Dash-Lines/DataFrame/FC2_labels_2.txt')

print(feature_FC1)
print(feature_FC2)
# Out:
# [[0.         0.         0.         ... 3.32232237 0.53497142 6.71018028]
#  [0.         0.         0.         ... 2.64994192 0.         9.06359482]
#  [0.         0.         0.         ... 5.72716618 0.         9.11935234]
#  ...
#  [0.         0.         0.         ... 0.39973658 0.         2.93420482]
#  [0.         1.45703292 0.         ... 3.89521027 0.         4.16184807]
#  [0.         0.         0.         ... 3.04137802 0.         8.37728119]]
# [[ 0.          6.6839633   9.71912098 ... 10.70267296  0.
#    0.        ]
#  [ 0.          7.49448156  9.2242918  ...  8.99572754  0.
#    0.        ]
#  [ 0.          9.2095499  15.12977028 ... 12.69464016  0.
#    0.        ]
#  ...
#  [ 0.          4.46453238 11.14836311 ...  8.57171059  0.
#    0.        ]
#  [ 0.          3.82225752  7.85776377 ...  5.56827068  0.
#    0.        ]
#  [ 0.          8.94981384 12.43922901 ... 11.61493301  0.
#    0.        ]]

# %%
#Tiến hành chia dữ liệu để thực hiện quá trình ra 2 phần train và test.
feature_FC1_train, feature_FC1_test, labels_FC1_train, labels_FC1_test = train_test_split(feature_FC1, labels_FC1, test_size = 0.2, random_state = 1)
feature_FC2_train, feature_FC2_test, labels_FC2_train, labels_FC2_test = train_test_split(feature_FC2, labels_FC2, test_size = 0.2, random_state = 1)

# %% [markdown]
# Lớp FC1

# %%
from sklearn.model_selection import KFold

X = np.concatenate((feature_FC1_train, feature_FC1_test), axis=0)
y = np.concatenate((labels_FC1_train, labels_FC1_test), axis=0)
clf_FC1 = make_pipeline(StandardScaler(), SVC(gamma='auto'))
kfold = KFold(n_splits=10, shuffle=True)

fold_idx = 1


for train_ids, val_ids in kfold.split(X, y):

  print("Bắt đầu train Fold ", fold_idx)
 
  # Train model
  clf_FC1.fit(X[train_ids], y[train_ids])
 
  # Tiến hành dự đoán dựa trên tập test
  predicted_FC1 = clf_FC1.predict(X[val_ids])

  # Hiển thị các chỉ số đánh giá chính.
  print(classification_report(predicted_FC1, y[val_ids]))
 
  # Thêm thông tin accuracy và loss vào list
  conf_FC1 = metrics.plot_confusion_matrix(clf_FC1, X[val_ids], y[val_ids])
  conf_FC1.figure_.suptitle("Confusion Matrix")
  print(f"Confusion matrix:\n{conf_FC1.confusion_matrix}")
  plt.show()
  # Sang Fold tiếp theo
  fold_idx = fold_idx + 1



# Tiến hành học từ tập dữ liệu train.




# Hiển thị ma trận Confusion matrix
# Out:
# Bắt đầu train Fold  1
#               precision    recall  f1-score   support
#
#          0.0       0.45      1.00      0.62         5
#          1.0       1.00      0.60      0.75        15
#
#     accuracy                           0.70        20
#    macro avg       0.73      0.80      0.69        20
# weighted avg       0.86      0.70      0.72        20
#
# Confusion matrix:
# [[5 6]
#  [0 9]]
# Bắt đầu train Fold  2
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.75      0.55         4
#          1.0       0.92      0.75      0.83        16
#
#     accuracy                           0.75        20
#    macro avg       0.68      0.75      0.69        20
# weighted avg       0.82      0.75      0.77        20
#
# Confusion matrix:
# [[ 3  4]
#  [ 1 12]]
# Bắt đầu train Fold  3
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.89      0.80         9
#          1.0       0.89      0.73      0.80        11
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# Confusion matrix:
# [[8 3]
#  [1 8]]
# Bắt đầu train Fold  4
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.89      0.76         9
#          1.0       0.88      0.64      0.74        11
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20
#
# Confusion matrix:
# [[8 4]
#  [1 7]]
# Bắt đầu train Fold  5
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.83      0.80        12
#          1.0       0.71      0.62      0.67         8
#
#     accuracy                           0.75        20
#    macro avg       0.74      0.73      0.73        20
# weighted avg       0.75      0.75      0.75        20
#
# Confusion matrix:
# [[10  3]
#  [ 2  5]]
# Bắt đầu train Fold  6
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.89      0.84         9
#          1.0       0.90      0.82      0.86        11
#
#     accuracy                           0.85        20
#    macro avg       0.85      0.85      0.85        20
# weighted avg       0.86      0.85      0.85        20
#
# Confusion matrix:
# [[8 2]
#  [1 9]]
# Bắt đầu train Fold  7
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.55      0.60        11
#          1.0       0.55      0.67      0.60         9
#
#     accuracy                           0.60        20
#    macro avg       0.61      0.61      0.60        20
# weighted avg       0.61      0.60      0.60        20
#
# Confusion matrix:
# [[6 3]
#  [5 6]]
# Bắt đầu train Fold  8
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.82      0.75        11
#          1.0       0.71      0.56      0.63         9
#
#     accuracy                           0.70        20
#    macro avg       0.70      0.69      0.69        20
# weighted avg       0.70      0.70      0.69        20
#
# Confusion matrix:
# [[9 4]
#  [2 5]]
# Bắt đầu train Fold  9
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.45      0.59        11
#          1.0       0.57      0.89      0.70         9
#
#     accuracy                           0.65        20
#    macro avg       0.70      0.67      0.64        20
# weighted avg       0.72      0.65      0.64        20
#
# Confusion matrix:
# [[5 1]
#  [6 8]]
# Bắt đầu train Fold  10
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.45      0.53        11
#          1.0       0.50      0.67      0.57         9
#
#     accuracy                           0.55        20
#    macro avg       0.56      0.56      0.55        20
# weighted avg       0.57      0.55      0.55        20
#
# Confusion matrix:
# [[5 3]
#  [6 6]]

# %%
# # tạo một bộ phân loại.
# clf_FC1 = make_pipeline(StandardScaler(), SVC(gamma='auto'))

# # Tiến hành học từ tập dữ liệu train.
# clf_FC1.fit(feature_FC1_train, labels_FC1_train)

# # Tiến hành dự đoán dựa trên tập test
# predicted_FC1 = clf_FC1.predict(feature_FC1_test)

# # Hiển thị các chỉ số đánh giá chính.
# print(classification_report(predicted_FC1, labels_FC1_test))

# # Hiển thị ma trận Confusion matrix
# conf_FC1 = metrics.plot_confusion_matrix(clf_FC1, feature_FC1_test, labels_FC1_test)
# conf_FC1.figure_.suptitle("Confusion Matrix")
# print(f"Confusion matrix:\n{conf_FC1.confusion_matrix}")
# plt.show()

# %% [markdown]
# Lớp FC2

# %%
X = np.concatenate((feature_FC2_train, feature_FC2_test), axis=0)
y = np.concatenate((labels_FC2_train, labels_FC2_test), axis=0)
clf_FC2 = make_pipeline(StandardScaler(), SVC(gamma='auto'))
kfold = KFold(n_splits=10, shuffle=True)

fold_idx = 1


for train_ids, val_ids in kfold.split(X, y):

  print("Bắt đầu train Fold ", fold_idx)
 
  # Train model
  clf_FC2.fit(X[train_ids], y[train_ids])
 
  # Tiến hành dự đoán dựa trên tập test
  predicted_FC2 = clf_FC2.predict(X[val_ids])

  # Hiển thị các chỉ số đánh giá chính.
  print(classification_report(predicted_FC2, y[val_ids]))
 
  # Thêm thông tin accuracy và loss vào list
  conf_FC2 = metrics.plot_confusion_matrix(clf_FC2, X[val_ids], y[val_ids])
  conf_FC2.figure_.suptitle("Confusion Matrix")
  print(f"Confusion matrix:\n{conf_FC2.confusion_matrix}")
  plt.show()
  # Sang Fold tiếp theo
  fold_idx = fold_idx + 1
# Out:
# Bắt đầu train Fold  1
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.55      0.57        11
#          1.0       0.50      0.56      0.53         9
#
#     accuracy                           0.55        20
#    macro avg       0.55      0.55      0.55        20
# weighted avg       0.55      0.55      0.55        20
#
# Confusion matrix:
# [[6 4]
#  [5 5]]
# Bắt đầu train Fold  2
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.71      0.56         7
#          1.0       0.78      0.54      0.64        13
#
#     accuracy                           0.60        20
#    macro avg       0.62      0.63      0.60        20
# weighted avg       0.66      0.60      0.61        20
#
# Confusion matrix:
# [[5 6]
#  [2 7]]
# Bắt đầu train Fold  3
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        10
#          1.0       0.50      0.50      0.50        10
#
#     accuracy                           0.50        20
#    macro avg       0.50      0.50      0.50        20
# weighted avg       0.50      0.50      0.50        20
#
# Confusion matrix:
# [[5 5]
#  [5 5]]
# Bắt đầu train Fold  4
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.60      0.67        10
#          1.0       0.67      0.80      0.73        10
#
#     accuracy                           0.70        20
#    macro avg       0.71      0.70      0.70        20
# weighted avg       0.71      0.70      0.70        20
#
# Confusion matrix:
# [[6 2]
#  [4 8]]
# Bắt đầu train Fold  5
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.67      0.76        12
#          1.0       0.64      0.88      0.74         8
#
#     accuracy                           0.75        20
#    macro avg       0.76      0.77      0.75        20
# weighted avg       0.79      0.75      0.75        20
#
# Confusion matrix:
# [[8 1]
#  [4 7]]
# Bắt đầu train Fold  6
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67         7
#          1.0       1.00      0.46      0.63        13
#
#     accuracy                           0.65        20
#    macro avg       0.75      0.73      0.65        20
# weighted avg       0.82      0.65      0.64        20
#
# Confusion matrix:
# [[7 7]
#  [0 6]]
# Bắt đầu train Fold  7
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.80      0.76        10
#          1.0       0.78      0.70      0.74        10
#
#     accuracy                           0.75        20
#    macro avg       0.75      0.75      0.75        20
# weighted avg       0.75      0.75      0.75        20
#
# Confusion matrix:
# [[8 3]
#  [2 7]]
# Bắt đầu train Fold  8
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.60      0.67        10
#          1.0       0.67      0.80      0.73        10
#
#     accuracy                           0.70        20
#    macro avg       0.71      0.70      0.70        20
# weighted avg       0.71      0.70      0.70        20
#
# Confusion matrix:
# [[6 2]
#  [4 8]]
# Bắt đầu train Fold  9
#               precision    recall  f1-score   support
#
#          0.0       0.89      1.00      0.94         8
#          1.0       1.00      0.92      0.96        12
#
#     accuracy                           0.95        20
#    macro avg       0.94      0.96      0.95        20
# weighted avg       0.96      0.95      0.95        20
#
# Confusion matrix:
# [[ 8  1]
#  [ 0 11]]
# Bắt đầu train Fold  10
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90        10
#          1.0       0.90      0.90      0.90        10
#
#     accuracy                           0.90        20
#    macro avg       0.90      0.90      0.90        20
# weighted avg       0.90      0.90      0.90        20
#
# Confusion matrix:
# [[9 1]
#  [1 9]]

# %%
# # tạo một bộ phân loại.
# clf_FC2 = make_pipeline(StandardScaler(), SVC(gamma='auto'))

# # Tiến hành học từ tập dữ liệu train.
# clf_FC2.fit(feature_FC2_train, labels_FC2_train)

# # Tiến hành dự đoán dựa trên tập test
# predicted_FC2 = clf_FC2.predict(feature_FC2_test)

# # Hiển thị các chỉ số đánh giá chính.
# print(classification_report(predicted_FC2, labels_FC2_test))

# # Hiển thị ma trận Confusion matrix
# conf_FC2 = metrics.plot_confusion_matrix(clf_FC2, feature_FC2_test, labels_FC2_test)
# conf_FC2.figure_.suptitle("Confusion Matrix")
# print(f"Confusion matrix:\n{conf_FC2.confusion_matrix}")
# plt.show()
